# %%
# !pip install pytesseract
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\pahadian\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\pahadian\anaconda3\lib\site-packages)
# ...

# %%
import pytesseract
from PIL import Image

# You need to specify the path to the tesseract executable
# For example, on Windows you might need to do:
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load your image
image = Image.open('test.jpeg')

# Use Tesseract to do OCR on the image
text = pytesseract.image_to_string(image)

print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
#       8 # Load your image
# ----> 9 image = Image.open('test.jpeg')
#      11 # Use Tesseract to do OCR on the image
#      12 text = pytesseract.image_to_string(image)
#
# File ~\Anaconda3\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.jpeg'

# %%
import pytesseract
from PIL import Image
import os

# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

image_dir = "Resolution"

for image_file in os.listdir(image_dir):
    image_path = os.path.join(image_dir, image_file)
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image)
    print(f"Text for {image_file}:")
    print(text)
    print("\n---\n")
# Out:
# Text for 00026cc1-678c-49a5-9d1c-8a60acb9a017.jpeg:
#
#
# ---
#
# Text for 0028ab3f-4b10-44cb-b799-ed4390a87bf6.jpeg:
# Number of CDs Mickey Buys (D) | Total Cost in Dollars (C)
#
#
#
# ---
#
# Text for 0180cb9a-8fbc-44c0-aa67-ee04bb335bd4.jpeg:
#
#
# ---
#
# Text for 026b304d-7e6f-404a-8e19-7390f3d0aa89.jpeg:
# a B Answer
#
#
#
# ---
#
# Text for 03ba45f3-a15c-4510-8355-c53b7940c7b6.jpeg:
# ut
# UNM
# NOTT Be
# aw these three rotations of langle XYz tops
# % ile XYZ 90 depres clockwise arouna 2
# PRoare
#
# rangle XYZ 180 degrees around Z.
#
# ‘wangie NYZ 270 degrees dockwise around 2,
#
#
#
# ---
#
# Text for 0498a2b3-9ff1-4438-934d-c794c1434383.jpeg:
#
#
# ---
#
# Text for 04f5dbfd-71ba-48b5-bd97-29fd7241e316.png:
# “
#
#
# ---
#
# Text for 056350df-19e5-474f-a238-8ccf23fbaa5b.jpeg:
# a_fe,
#
#
#
# ---
#
# Text for 059dda12-492e-4bb7-9633-561d26a948b0.jpeg:
#
#
# ---
#
# Text for 05c18b8f-2f4d-462a-b833-2605bb960e34.jpeg:
#
#
# ---
#
# ...

# %%
import pytesseract
from PIL import Image
import os

# pytesseract.pytesseract.tesseract_cmd = r'your_actual_path\tesseract.exe'  # replace with your actual path
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

image_dir = "Resolution"

for image_file in os.listdir(image_dir):
    image_path = os.path.join(image_dir, image_file)
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image)

    # Create a corresponding .txt file for each image
    output_file = os.path.splitext(image_file)[0] + '.txt'
    with open(output_file, 'w') as file:
        file.write(text)

# %%
import pytesseract
from PIL import Image
import os

# pytesseract.pytesseract.tesseract_cmd = r'your_actual_path\tesseract.exe'  # replace with your actual path

image_dir = "Resolution"
output_dir = "OCRResult"

# Create the output folder if it doesn't already exist
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

for image_file in os.listdir(image_dir):
    image_path = os.path.join(image_dir, image_file)
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image)

    # Create a corresponding .txt file for each image in the output folder
    output_file = os.path.splitext(image_file)[0] + '.txt'
    output_path = os.path.join(output_dir, output_file)

    with open(output_path, 'w') as file:
        file.write(text)

# %%
import os 
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import os
from paddleocr import PaddleOCR

# Create an OCR agent
ocr = PaddleOCR(use_gpu=False)

image_dir = "Resolution"
output_dir = "PaddleOCRResult"

# Create the output folder if it doesn't already exist
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

for image_file in os.listdir(image_dir):
    image_path = os.path.join(image_dir, image_file)
    result = ocr.ocr(image_path)

    # Create a corresponding .txt file for each image in the output folder
    output_file = os.path.splitext(image_file)[0] + '.txt'
    output_path = os.path.join(output_dir, output_file)

   # with open(output_path, 'w') as file:
        #for line in result:
            #line_text = ' '.join([word_info[-1][0] for word_info in line])
            #file.write(line_text + '\n')

    with open(output_path, 'w', encoding='utf-8') as file:
        for line in result:
            line_text = ' '.join([word_info[-1][0] for word_info in line])
            file.write(line_text + '\n')
# Out:
# [2023/05/17 14:13:15] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\pahadian/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\pahadian/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_lengt
# ...

# %%
import os
from paddleocr import PaddleOCR

# Create an OCR agent
ocr = PaddleOCR(use_gpu=False)

image_dir = "dr"
output_dir = "dd"

# Create the output folder if it doesn't already exist
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

for image_file in os.listdir(image_dir):
    image_path = os.path.join(image_dir, image_file)
    result = ocr.ocr(image_path)

    # Create a corresponding .txt file for each image in the output folder
    output_file = os.path.splitext(image_file)[0] + '.txt'
    output_path = os.path.join(output_dir, output_file)

   # with open(output_path, 'w') as file:
        #for line in result:
            #line_text = ' '.join([word_info[-1][0] for word_info in line])
            #file.write(line_text + '\n')

    with open(output_path, 'w', encoding='utf-8') as file:
        for line in result:
            line_text = ' '.join([word_info[-1][0] for word_info in line])
            file.write(line_text + '\n')
# Out:
# [2023/05/19 10:30:18] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\pahadian/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\pahadian/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_lengt
# ...

# %%
import pytesseract
from PIL import Image
import os

# pytesseract.pytesseract.tesseract_cmd = r'your_actual_path\tesseract.exe'  # replace with your actual path

image_dir = "dr"
output_dir = "ddc"

# Create the output folder if it doesn't already exist
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

for image_file in os.listdir(image_dir):
    image_path = os.path.join(image_dir, image_file)
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image)

    # Create a corresponding .txt file for each image in the output folder
    output_file = os.path.splitext(image_file)[0] + '.txt'
    output_path = os.path.join(output_dir, output_file)

    with open(output_path, 'w') as file:
        file.write(text)

# %%
import cv2
import pytesseract

def process_image(image_path):
    # Load the image from file
    image = cv2.imread(image_path)

    # Convert the image to gray scale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use Tesseract to do OCR on the image
    text = pytesseract.image_to_string(gray, config='--psm 6')

    return text

image_path = "Capture.PNG"  # replace with your image path
result = process_image(image_path)
print(result)
# Out:
# #1 ‘Find the missing number. Show how you found it.
# {0 SL
# 3 eM, At lo=Gi7 7
# Multiply SXF Now add \q WE ANC numerador
# 3h = 224 B28 —
# UyF=28\_Z Wa et 13) 50, 15-4
# Malhipy Ae Swbrtoct oy +3
# #2 Find the missing number. Show how you fouind it.

# %%
#Read Formula
import os
import cv2
import pytesseract

def process_image(image_path):
    # Load the image from file
    image = cv2.imread(image_path)

    # Convert the image to gray scale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use Tesseract to do OCR on the image
    text = pytesseract.image_to_string(gray, config='--psm 6')

    return text

input_dir = 'Resolution'  # replace with your input directory
output_dir = 'formulaResult'  # replace with your output directory

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for filename in os.listdir(input_dir):
    if filename.endswith('.png') or filename.endswith('.jpeg'):  # or whatever file types you're using
        print(f'Processing {filename}')
        image_path = os.path.join(input_dir, filename)
        result = process_image(image_path)

        # Construct the output file path by changing the extension to .txt
        output_file_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '.txt')

        # Write the OCR result to the output file
        with open(output_file_path, 'w') as output_file:
            output_file.write(result)
# Out:
# Processing 00026cc1-678c-49a5-9d1c-8a60acb9a017.jpeg
# Processing 0028ab3f-4b10-44cb-b799-ed4390a87bf6.jpeg
# Processing 0180cb9a-8fbc-44c0-aa67-ee04bb335bd4.jpeg
# Processing 026b304d-7e6f-404a-8e19-7390f3d0aa89.jpeg
# Processing 03ba45f3-a15c-4510-8355-c53b7940c7b6.jpeg
# Processing 0498a2b3-9ff1-4438-934d-c794c1434383.jpeg
# Processing 04f5dbfd-71ba-48b5-bd97-29fd7241e316.png
# Processing 056350df-19e5-474f-a238-8ccf23fbaa5b.jpeg
# Processing 059dda12-492e-4bb7-9633-561d26a948b0.jpeg
# Processing 05c18b8f-2f4d-462a-b833-2605bb960e34.jpeg
# Processing 06c4c8e1-c12e-4a22-b5b4-bcaa8ffbf967.jpeg
# Processing 073115b6-6972-485d-8e99-6a5e02511ff1.jpeg
# Processing 07f0deb9-c9f6-4580-9643-c94f5c66507d.jpeg
# Processing 091edf85-6d36-4be8-8c20-df39593c5c4e.jpeg
# Processing 09c33b0f-bd1c-4651-a3b7-98af3fc8a882.jpeg
# Processing 0a7e64c1-61d1-4f5c-9259-81cb01556731.jpeg
# Processing 0a8fa2e2-78da-49b9-8eb5-3c146767c122.jpeg
# Processing 0b03263c-bd5b-4553-915c-1e0c1687f1c7.png
# ...

# %%
import requests
import base64
import json

def process_image(image_path):
    # Load the image and encode it in base64
    with open(image_path, "rb") as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode('utf-8')

    # Create the JSON payload
    payload = {
        "src": encoded_string,
        "formats": ["text", "data", "html"],
    }

    # These are the headers for the API request
    headers = {
        'app_id': 'token_e06840c31fbfd28c2aba38207e417c4e',  # replace with your app id
        'app_key': '1649699265744',  # replace with your app key
        'Content-type': 'application/json',
    }

    # Send the API request
    response = requests.post('https://api.mathpix.com/v3/text', headers=headers, data=json.dumps(payload))

    return response.json()

image_path = "Capture.PNG"  # replace with your image path
result = process_image(image_path)
print(result)
# Out:
# {'error': 'Invalid credentials', 'error_info': {'id': 'http_unauthorized', 'message': 'Invalid credentials'}}

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
#Read Formula
import os
import cv2
import pytesseract

def process_image(image_path):
    # Load the image from file
    image = cv2.imread(image_path)

    # Convert the image to gray scale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use Tesseract to do OCR on the image
    text = pytesseract.image_to_string(gray, config='--psm 6')

    return text

input_dir = 'grade6'  # replace with your input directory
output_dir = 'grade6tesuly'  # replace with your output directory

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for filename in os.listdir(input_dir):
    if filename.endswith('.png') or filename.endswith('.jpg'):  # or whatever file types you're using
        print(f'Processing {filename}')
        image_path = os.path.join(input_dir, filename)
        result = process_image(image_path)

        # Construct the output file path by changing the extension to .txt
        output_file_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '.txt')

        # Write the OCR result to the output file
        with open(output_file_path, 'w') as output_file:
            output_file.write(result)
# Out:
# Processing Grade6_sample11024_1.jpg
# Processing Grade6_sample11024_10.jpg
# Processing Grade6_sample11024_100.jpg
# Processing Grade6_sample11024_101.jpg
# Processing Grade6_sample11024_102.jpg
# Processing Grade6_sample11024_103.jpg
# Processing Grade6_sample11024_104.jpg
# Processing Grade6_sample11024_105.jpg
# Processing Grade6_sample11024_106.jpg
# Processing Grade6_sample11024_107.jpg
# Processing Grade6_sample11024_108.jpg
# Processing Grade6_sample11024_109.jpg
# Processing Grade6_sample11024_11.jpg
# Processing Grade6_sample11024_110.jpg
# Processing Grade6_sample11024_111.jpg
# Processing Grade6_sample11024_112.jpg
# Processing Grade6_sample11024_113.jpg
# Processing Grade6_sample11024_114.jpg
# Processing Grade6_sample11024_115.jpg
# Processing Grade6_sample11024_116.jpg
# Processing Grade6_sample11024_117.jpg
# Processing Grade6_sample11024_118.jpg
# Processing Grade6_sample11024_119.jpg
# Processing Grade6_sample11024_12.jpg
# Processing Grade6_sample11024_120.jpg
# ...
